# %%
import os, tensorflow as tf, matplotlib.pyplot as plt, numpy as np, seaborn as sns, pandas as pd
from PIL import Image
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# %%
img_height, img_width = 256, 256
batch_size = 32
random_seed = 1337
split_ratio = 0.35

train_dataset = tf.keras.preprocessing.image_dataset_from_directory('../data',
                                                                    validation_split=None,
                                                                    subset=None,
                                                                    seed=random_seed,
                                                                    label_mode='int',
                                                                    color_mode='rgb',
                                                                    image_size=(img_height, img_width),
                                                                    batch_size=batch_size)

# train_dataset = tf.keras.preprocessing.image_dataset_from_directory('../data',
#                                                                     validation_split=split_ratio,
#                                                                     subset='training',
#                                                                     seed=random_seed,
#                                                                     label_mode='int',
#                                                                     color_mode='rgb',
#                                                                     image_size=(img_height, img_width),
#                                                                     batch_size=batch_size)

# val_dataset = tf.keras.preprocessing.image_dataset_from_directory('../data',
#                                                                     validation_split=split_ratio,
#                                                                     subset="validation",
#                                                                     seed=random_seed,                                                                  
#                                                                     label_mode='int',
#                                                                     color_mode='rgb',
#                                                                     image_size=(img_height, img_width),
#                                                                     batch_size=batch_size)

class_names = train_dataset.class_names
print(f'Class names: {class_names}')
# Out:
# Found 7155 files belonging to 8 classes.
# Class names: ['body', 'conditioner', 'cotton', 'facial', 'sebum', 'serum', 'shampoo', 'toner']

# %%
test_dataset = tf.keras.preprocessing.image_dataset_from_directory('../test_predictions',
                                                                    validation_split=None,
                                                                    subset=None,
                                                                    seed=random_seed,
                                                                    label_mode='int',
                                                                    color_mode='rgb',
                                                                    image_size=(img_height, img_width),
                                                                    batch_size=batch_size)
# Out:
# Found 1662 files belonging to 8 classes.

# %%
'''Color'''
plt.figure(figsize=(30, 20))
plt.rcParams['axes.titlesize'] = 20
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(f'{int(labels[i])}:{class_names[(labels[i])]}')
        plt.axis("off")

# '''Grayscale'''        
# plt.figure(figsize=(30, 20))
# plt.rcParams['axes.titlesize'] = 20
# for images, labels in train_dataset.take(1):
#     for i in range(9):
#         ax = plt.subplot(3, 3, i + 1)
#         plt.imshow(tf.squeeze(images[i].numpy().astype("uint8")), cmap='gray', vmin=0, vmax=255)
#         plt.title(f'{int(labels[i])}:{class_names[(labels[i])]}')
#         plt.axis("off")

# %%
def check_predictions(i_type):
    counter = 0
    print(f'Predicting for: {i_type}')
    
    for file in os.listdir(f'../test_predictions/{i_type}'):
        img = keras.preprocessing.image.load_img(path=os.path.join(f'../test_predictions/{i_type}/', file), 
                                            color_mode='rgb',
                                            target_size=(img_height, img_width))
        img_arr = keras.preprocessing.image.img_to_array(img)
        img_arr = tf.expand_dims(img_arr, 0)
        pred = model.predict(img_arr)
        scores = tf.nn.softmax(pred[0])
        pred_class = np.argmax(scores)
        if class_names[pred_class] != i_type:
            counter += 1
            print(f'Predicted: {class_names[pred_class]} for: {file}')
            
    print(f'Number of misclassifications: {counter}')

# %%
def create_model():
    num_classes = len(class_names)

    model = Sequential([
        layers.experimental.preprocessing.RandomFlip(mode='horizontal_and_vertical', seed=random_seed),
        layers.experimental.preprocessing.RandomRotation(factor=0.3, seed=random_seed),
        layers.experimental.preprocessing.RandomZoom(height_factor=0.3, width_factor=0.3, seed=random_seed),
#         layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        
        # Conv 1
        layers.Conv2D(64, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), strides=(2,2)),

        # Conv 2
        layers.Conv2D(128, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), strides=(2,2)),
        
        # Conv 3
        layers.Conv2D(256, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.Conv2D(256, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), strides=(2,2)),

        # Conv 4
        layers.Conv2D(512, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), strides=(2,2)),

        # Conv 5
        layers.Conv2D(1024, (3,3), activation='relu', padding='same', 
                      kernel_initializer=tf.keras.initializers.GlorotNormal(seed=random_seed)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), strides=(2,2)),

        layers.Flatten(),
        layers.Dropout(0.2, seed=random_seed),
        layers.Dense(32, activation='relu'), # 32
        layers.BatchNormalization(),
        layers.Dropout(0.2, seed=random_seed), #.15
        layers.Dense(num_classes)])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=[tf.metrics.SparseCategoricalAccuracy()])

    return model

# %% [markdown]
# ##### Stratified Kfold

# %%
from sklearn.model_selection import StratifiedKFold

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=random_seed)

# %%
x = train_dataset.take(-1)

# %%
data, labels = [], []

for images, targets in x:
    for i in range(len(images)):
        data.append(images[i].numpy())
        labels.append(targets[i].numpy())
        
data = np.array(data)        
labels = np.array(labels)

# %%
avg_val_loss, avg_val_acc, eval_loss, eval_acc = [], [], [], []

for f, (train_idx, test_idx) in enumerate(folds.split(data, labels)):
    fold = f+1
    print(f'Fold: {fold}')
#     print(f'Train Dataset size: {len(train_idx)}, Val Dataset Size: {len(test_idx)}')
    
    model = create_model()
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              min_delta=0, 
                                              patience=10, 
                                              verbose=1, 
                                              mode='min',
                                              baseline=None, 
                                              restore_best_weights=False)
    
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=f'./{fold}_glorot_best_model.h5', 
                                                monitor='val_loss', 
                                                verbose=1,
                                                save_best_only=True, 
                                                mode='min')
    epochs = 1000

    history = model.fit(x=data[train_idx], 
                        y=labels[train_idx],
#                         validation_split=split_ratio,
                        validation_data=(data[test_idx], labels[test_idx]),
                        epochs=epochs,
                        batch_size=batch_size,
                        verbose=1, callbacks=[early_stop, checkpoint])
    
    avg_val_loss.append(np.mean(history.history['val_loss']))
    avg_val_acc.append(np.mean(history.history['val_sparse_categorical_accuracy']))
    
    model = load_model(f'./{fold}_glorot_best_model.h5')
    eval_res = model.evaluate(test_dataset, return_dict=True)
    eval_loss.append(eval_res['loss'])
    eval_acc.append(eval_res['sparse_categorical_accuracy'])

    print('*'*100)
    print(f'End of fold: {fold}')
    print('*'*100)
    print('\n')
# Out:
# Fold: 1
# Epoch 1/1000
#   2/202 [..............................] - ETA: 22s - loss: 2.9784 - sparse_categorical_accuracy: 0.1250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1189 - sparse_categorical_accuracy: 0.9814
# Epoch 00024: val_loss improved from 0.09573 to 0.08973, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 43s 213ms/step - loss: 0.1189 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9888
# Epoch 25/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1097 - sparse_categorical_accuracy: 0.9859
# Epoch 00025: val_loss did not improve from 0.08973
# 202/202 [==============================] - 43s 212ms/step - loss: 0.1097 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.0945 - val_sparse_categorical_accuracy: 0.9888
# Epoch 26/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1103 - sparse_categorical_accuracy: 0.9857
# Epoch 00026: val_loss improved from 0.08973 to 0.08806, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 44s 216ms/step - loss: 0.1103 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0881 - val_sparse_categorical_accuracy: 0.9930
# Epoch 27/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1040 - sparse_categorical_accuracy: 0.9871
# Epoch 00027: val_loss improved from 0.08806 to 0.07724, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 43s 213ms/step - loss: 0.1040 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.0772 - val_sparse_categorical_accuracy: 0.9916
# Epoch 28/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0990 - sparse_categorical_accuracy: 0.9866
# Epoch 00028: val_loss improved from 0.07724 to 0.06210, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 43s 213ms/step - loss: 0.0990 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.0621 - val_sparse_categorical_accuracy: 0.9930
# Epoch 29/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0925 - sparse_categorical_accuracy: 0.9902
# Epoch 00029: val_loss did not improve from 0.06210
# 202/202 [==============================] - 43s 213ms/step - loss: 0.0925 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.0651 - val_sparse_categorical_accuracy: 0.9916
# Epoch 30/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0864 - sparse_categorical_accuracy: 0.9910
# Epoch 00030: val_loss did not improve from 0.06210
# 202/202 [==============================] - 43s 215ms/step - loss: 0.0864 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.0679 - val_sparse_categorical_accuracy: 0.9916
# Epoch 31/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0898 - sparse_categorical_accuracy: 0.9880
# Epoch 00031: val_loss did not improve from 0.06210
# 202/202 [==============================] - 43s 215ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0781 - val_sparse_categorical_accuracy: 0.9860
# Epoch 32/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0808 - sparse_categorical_accuracy: 0.9897
# Epoch 00032: val_loss improved from 0.06210 to 0.04938, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 44s 216ms/step - loss: 0.0808 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0494 - val_sparse_categorical_accuracy: 0.9972
# Epoch 33/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0793 - sparse_categorical_accuracy: 0.9896
# Epoch 00033: val_loss did not improve from 0.04938
# 202/202 [==============================] - 43s 213ms/step - loss: 0.0793 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9860
# Epoch 34/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0701 - sparse_categorical_accuracy: 0.9925
# Epoch 00034: val_loss did not improve from 0.04938
# 202/202 [==============================] - 43s 213ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0497 - val_sparse_categorical_accuracy: 0.9958
# Epoch 35/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0631 - sparse_categorical_accuracy: 0.9949
# Epoch 00035: val_loss improved from 0.04938 to 0.03898, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 44s 216ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0390 - val_sparse_categorical_accuracy: 0.9986
# Epoch 36/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0708 - sparse_categorical_accuracy: 0.9902
# Epoch 00036: val_loss did not improve from 0.03898
# 202/202 [==============================] - 44s 216ms/step - loss: 0.0708 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.0531 - val_sparse_categorical_accuracy: 0.9958
# Epoch 37/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0669 - sparse_categorical_accuracy: 0.9925
# Epoch 00037: val_loss did not improve from 0.03898
# 202/202 [==============================] - 42s 207ms/step - loss: 0.0669 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0444 - val_sparse_categorical_accuracy: 0.9972
# Epoch 38/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0635 - sparse_categorical_accuracy: 0.9925
# Epoch 00038: val_loss did not improve from 0.03898
# 202/202 [==============================] - 40s 200ms/step - loss: 0.0635 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0523 - val_sparse_categorical_accuracy: 0.9902
# Epoch 39/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0588 - sparse_categorical_accuracy: 0.9949
# Epoch 00039: val_loss improved from 0.03898 to 0.03391, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 45s 222ms/step - loss: 0.0588 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0339 - val_sparse_categorical_accuracy: 0.9972
# Epoch 40/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0568 - sparse_categorical_accuracy: 0.9952
# Epoch 00040: val_loss did not improve from 0.03391
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0387 - val_sparse_categorical_accuracy: 0.9958
# Epoch 41/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0635 - sparse_categorical_accuracy: 0.9916
# Epoch 00041: val_loss did not improve from 0.03391
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0635 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0525 - val_sparse_categorical_accuracy: 0.9972
# Epoch 42/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0535 - sparse_categorical_accuracy: 0.9952
# Epoch 00042: val_loss did not improve from 0.03391
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0535 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0352 - val_sparse_categorical_accuracy: 0.9986
# Epoch 43/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0496 - sparse_categorical_accuracy: 0.9949
# Epoch 00043: val_loss did not improve from 0.03391
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0423 - val_sparse_categorical_accuracy: 0.9944
# Epoch 44/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0509 - sparse_categorical_accuracy: 0.9949
# Epoch 00044: val_loss improved from 0.03391 to 0.02932, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 49s 241ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0293 - val_sparse_categorical_accuracy: 0.9986
# Epoch 45/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0481 - sparse_categorical_accuracy: 0.9961
# Epoch 00045: val_loss did not improve from 0.02932
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0312 - val_sparse_categorical_accuracy: 0.9972
# Epoch 46/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0457 - sparse_categorical_accuracy: 0.9972
# Epoch 00046: val_loss improved from 0.02932 to 0.02388, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0457 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0239 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0469 - sparse_categorical_accuracy: 0.9955
# Epoch 00047: val_loss did not improve from 0.02388
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 0.9972
# Epoch 48/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0483 - sparse_categorical_accuracy: 0.9957
# Epoch 00048: val_loss did not improve from 0.02388
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0363 - val_sparse_categorical_accuracy: 0.9972
# Epoch 49/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0405 - sparse_categorical_accuracy: 0.9969
# Epoch 00049: val_loss did not improve from 0.02388
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0471 - val_sparse_categorical_accuracy: 0.9888
# Epoch 50/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0474 - sparse_categorical_accuracy: 0.9957
# Epoch 00050: val_loss did not improve from 0.02388
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0309 - val_sparse_categorical_accuracy: 0.9972
# Epoch 51/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0401 - sparse_categorical_accuracy: 0.9963
# Epoch 00051: val_loss did not improve from 0.02388
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0429 - val_sparse_categorical_accuracy: 0.9944
# Epoch 52/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0392 - sparse_categorical_accuracy: 0.9964
# Epoch 00052: val_loss did not improve from 0.02388
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0254 - val_sparse_categorical_accuracy: 0.9958
# Epoch 53/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0386 - sparse_categorical_accuracy: 0.9964
# Epoch 00053: val_loss improved from 0.02388 to 0.02362, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0236 - val_sparse_categorical_accuracy: 0.9958
# Epoch 54/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0364 - sparse_categorical_accuracy: 0.9980
# Epoch 00054: val_loss did not improve from 0.02362
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9986
# Epoch 55/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0371 - sparse_categorical_accuracy: 0.9967
# Epoch 00055: val_loss did not improve from 0.02362
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0258 - val_sparse_categorical_accuracy: 0.9986
# Epoch 56/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0335 - sparse_categorical_accuracy: 0.9977
# Epoch 00056: val_loss improved from 0.02362 to 0.01931, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0335 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0319 - sparse_categorical_accuracy: 0.9970
# Epoch 00057: val_loss did not improve from 0.01931
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9986
# Epoch 58/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0323 - sparse_categorical_accuracy: 0.9984
# Epoch 00058: val_loss did not improve from 0.01931
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9972
# Epoch 59/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0324 - sparse_categorical_accuracy: 0.9974
# Epoch 00059: val_loss did not improve from 0.01931
# 202/202 [==============================] - 48s 236ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9972
# Epoch 60/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0323 - sparse_categorical_accuracy: 0.9980
# Epoch 00060: val_loss did not improve from 0.01931
# 202/202 [==============================] - 48s 237ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9972
# Epoch 61/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0367 - sparse_categorical_accuracy: 0.9955
# Epoch 00061: val_loss did not improve from 0.01931
# 202/202 [==============================] - 48s 237ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 0.9986
# Epoch 62/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0316 - sparse_categorical_accuracy: 0.9970
# Epoch 00062: val_loss did not improve from 0.01931
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9972
# Epoch 63/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0361 - sparse_categorical_accuracy: 0.9960
# Epoch 00063: val_loss did not improve from 0.01931
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9986
# Epoch 64/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0311 - sparse_categorical_accuracy: 0.9977
# Epoch 00064: val_loss improved from 0.01931 to 0.01488, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 48s 240ms/step - loss: 0.0311 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 0.9986
# Epoch 65/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0254 - sparse_categorical_accuracy: 0.9989
# Epoch 00065: val_loss did not improve from 0.01488
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 0.9972
# Epoch 66/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0243 - sparse_categorical_accuracy: 0.9989
# Epoch 00066: val_loss did not improve from 0.01488
# 202/202 [==============================] - 48s 238ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 0.9986
# Epoch 67/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0235 - sparse_categorical_accuracy: 0.9991
# Epoch 00067: val_loss improved from 0.01488 to 0.01311, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 49s 241ms/step - loss: 0.0235 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 0.9986
# Epoch 68/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0256 - sparse_categorical_accuracy: 0.9978
# Epoch 00068: val_loss did not improve from 0.01311
# 202/202 [==============================] - 48s 238ms/step - loss: 0.0256 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 0.9986
# Epoch 69/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0254 - sparse_categorical_accuracy: 0.9980
# Epoch 00069: val_loss did not improve from 0.01311
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 1.0000
# Epoch 70/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0237 - sparse_categorical_accuracy: 0.9983
# Epoch 00070: val_loss improved from 0.01311 to 0.01201, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 1.0000
# Epoch 71/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0231 - sparse_categorical_accuracy: 0.9989
# Epoch 00071: val_loss did not improve from 0.01201
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 1.0000
# Epoch 72/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0214 - sparse_categorical_accuracy: 0.9989
# Epoch 00072: val_loss did not improve from 0.01201
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9986
# Epoch 73/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0332 - sparse_categorical_accuracy: 0.9958
# Epoch 00073: val_loss did not improve from 0.01201
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9972
# Epoch 74/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0232 - sparse_categorical_accuracy: 0.9986
# Epoch 00074: val_loss improved from 0.01201 to 0.01117, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 1.0000
# Epoch 75/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0220 - sparse_categorical_accuracy: 0.9991
# Epoch 00075: val_loss did not improve from 0.01117
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 1.0000
# Epoch 76/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0230 - sparse_categorical_accuracy: 0.9980
# Epoch 00076: val_loss did not improve from 0.01117
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0196 - val_sparse_categorical_accuracy: 1.0000
# Epoch 77/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0197 - sparse_categorical_accuracy: 0.9994
# Epoch 00077: val_loss improved from 0.01117 to 0.00823, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 48s 235ms/step - loss: 0.0197 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0082 - val_sparse_categorical_accuracy: 1.0000
# Epoch 78/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0196 - sparse_categorical_accuracy: 0.9988
# Epoch 00078: val_loss improved from 0.00823 to 0.00775, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 50s 246ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0077 - val_sparse_categorical_accuracy: 1.0000
# Epoch 79/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0190 - sparse_categorical_accuracy: 0.9986
# Epoch 00079: val_loss did not improve from 0.00775
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 1.0000
# Epoch 80/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0200 - sparse_categorical_accuracy: 0.9983
# Epoch 00080: val_loss did not improve from 0.00775
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 81/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0199 - sparse_categorical_accuracy: 0.9984
# Epoch 00081: val_loss did not improve from 0.00775
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 0.9972
# Epoch 82/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0222 - sparse_categorical_accuracy: 0.9981
# Epoch 00082: val_loss did not improve from 0.00775
# 202/202 [==============================] - 46s 226ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0092 - val_sparse_categorical_accuracy: 1.0000
# Epoch 83/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0188 - sparse_categorical_accuracy: 0.9991
# Epoch 00083: val_loss did not improve from 0.00775
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 0.9986
# Epoch 84/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0203 - sparse_categorical_accuracy: 0.9986
# Epoch 00084: val_loss did not improve from 0.00775
# 202/202 [==============================] - 46s 226ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0098 - val_sparse_categorical_accuracy: 1.0000
# Epoch 85/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0192 - sparse_categorical_accuracy: 0.9980
# Epoch 00085: val_loss improved from 0.00775 to 0.00702, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 46s 229ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 1.0000
# Epoch 86/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0164 - sparse_categorical_accuracy: 0.9995
# Epoch 00086: val_loss did not improve from 0.00702
# 202/202 [==============================] - 46s 230ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 1.0000
# Epoch 87/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0183 - sparse_categorical_accuracy: 0.9980
# Epoch 00087: val_loss did not improve from 0.00702
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0183 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 0.9986
# Epoch 88/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0142 - sparse_categorical_accuracy: 0.9992
# Epoch 00088: val_loss improved from 0.00702 to 0.00679, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 46s 229ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0068 - val_sparse_categorical_accuracy: 1.0000
# Epoch 89/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0205 - sparse_categorical_accuracy: 0.9975
# Epoch 00089: val_loss did not improve from 0.00679
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9972
# Epoch 90/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0244 - sparse_categorical_accuracy: 0.9974
# Epoch 00090: val_loss did not improve from 0.00679
# 202/202 [==============================] - 46s 230ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 1.0000
# Epoch 91/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0156 - sparse_categorical_accuracy: 0.9991
# Epoch 00091: val_loss improved from 0.00679 to 0.00629, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 44s 217ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 1.0000
# Epoch 92/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0129 - sparse_categorical_accuracy: 0.9997
# Epoch 00092: val_loss did not improve from 0.00629
# 202/202 [==============================] - 48s 238ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 1.0000
# Epoch 93/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0155 - sparse_categorical_accuracy: 0.9988
# Epoch 00093: val_loss did not improve from 0.00629
# 202/202 [==============================] - 46s 230ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0075 - val_sparse_categorical_accuracy: 1.0000
# Epoch 94/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0141 - sparse_categorical_accuracy: 0.9991
# Epoch 00094: val_loss did not improve from 0.00629
# 202/202 [==============================] - 47s 230ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0110 - val_sparse_categorical_accuracy: 0.9986
# Epoch 95/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0159 - sparse_categorical_accuracy: 0.9988
# Epoch 00095: val_loss improved from 0.00629 to 0.00626, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 235ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 1.0000
# Epoch 96/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0113 - sparse_categorical_accuracy: 0.9998
# Epoch 00096: val_loss improved from 0.00626 to 0.00594, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 1.0000
# Epoch 97/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0190 - sparse_categorical_accuracy: 0.9972
# Epoch 00097: val_loss did not improve from 0.00594
# 202/202 [==============================] - 46s 227ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0075 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0140 - sparse_categorical_accuracy: 0.9991
# Epoch 00098: val_loss improved from 0.00594 to 0.00485, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 99/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0126 - sparse_categorical_accuracy: 0.9995
# Epoch 00099: val_loss did not improve from 0.00485
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 0.9986
# Epoch 100/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0131 - sparse_categorical_accuracy: 0.9991
# Epoch 00100: val_loss improved from 0.00485 to 0.00477, saving model to .\1_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 0.9986
# Epoch 101/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0136 - sparse_categorical_accuracy: 0.9992
# Epoch 00101: val_loss did not improve from 0.00477
# 202/202 [==============================] - 46s 230ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 1.0000
# Epoch 102/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0124 - sparse_categorical_accuracy: 0.9989
# Epoch 00102: val_loss did not improve from 0.00477
# 202/202 [==============================] - 46s 230ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 1.0000
# Epoch 103/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0103 - sparse_categorical_accuracy: 0.9997
# Epoch 00103: val_loss did not improve from 0.00477
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 1.0000
# Epoch 104/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0142 - sparse_categorical_accuracy: 0.9989
# Epoch 00104: val_loss did not improve from 0.00477
# 202/202 [==============================] - 46s 229ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 1.0000
# Epoch 105/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0117 - sparse_categorical_accuracy: 0.9994
# Epoch 00105: val_loss did not improve from 0.00477
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 0.9986
# Epoch 106/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0127 - sparse_categorical_accuracy: 0.9991
# Epoch 00106: val_loss did not improve from 0.00477
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 107/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0126 - sparse_categorical_accuracy: 0.9989
# Epoch 00107: val_loss did not improve from 0.00477
# 202/202 [==============================] - 48s 238ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 1.0000
# Epoch 108/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0118 - sparse_categorical_accuracy: 0.9989
# Epoch 00108: val_loss did not improve from 0.00477
# 202/202 [==============================] - 51s 253ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 109/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0106 - sparse_categorical_accuracy: 0.9995
# Epoch 00109: val_loss did not improve from 0.00477
# 202/202 [==============================] - 50s 245ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 1.0000
# Epoch 110/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0102 - sparse_categorical_accuracy: 0.9995
# Epoch 00110: val_loss did not improve from 0.00477
# 202/202 [==============================] - 50s 246ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 1.0000
# Epoch 00110: early stopping
# 52/52 [==============================] - 9s 181ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9976
# ****************************************************************************************************
# End of fold: 1
# ****************************************************************************************************
#
#
# Fold: 2
# Epoch 1/1000
#   2/202 [..............................] - ETA: 23s - loss: 2.9239 - sparse_categorical_accuracy: 0.0781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0677s vs `on_train_batch_end` time: 0.1673s). Check your callbacks.
# 202/202 [==============================] - ETA: 0s - loss: 1.9250 - sparse_categorical_accuracy: 0.3410
# Epoch 00001: val_loss improved from inf to 2.47095, saving model to .\2_glorot_best_model.h5
# 202/202 [==============================] - 49s 244ms/step - loss: 1.9250 - sparse_categorical_accuracy: 0.3410 - val_loss: 2.4709 - val_sparse_categorical_accuracy: 0.1480
# Epoch 2/1000
# 202/202 [==============================] - ETA: 0s - loss: 1.2179 - sparse_categorical_accuracy: 0.5889
# Epoch 00002: val_loss improved from 2.47095 to 1.39175, saving model to .\2_glorot_best_model.h5
# 202/202 [==============================] - 48s 237ms/step - loss: 1.2179 - sparse_categorical_accuracy: 0.5889 - val_loss: 1.3917 - val_sparse_categorical_accuracy: 0.4623
# Epoch 3/1000
# 202/202 [==============================] - ETA: 0s - loss: 0
1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1853 - sparse_categorical_accuracy: 0.9685
# Epoch 00015: val_loss did not improve from 0.14537
# 202/202 [==============================] - 48s 237ms/step - loss: 0.1853 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.1496 - val_sparse_categorical_accuracy: 0.9707
# Epoch 16/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1709 - sparse_categorical_accuracy: 0.9717
# Epoch 00016: val_loss improved from 0.14537 to 0.13097, saving model to .\2_glorot_best_model.h5
# 202/202 [==============================] - 52s 259ms/step - loss: 0.1709 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.1310 - val_sparse_categorical_accuracy: 0.9749
# Epoch 17/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1606 - sparse_categorical_accuracy: 0.9759
# Epoch 00017: val_loss did not improve from 0.13097
# 202/202 [==============================] - 53s 264ms/step - loss: 0.1606 - sparse_categorical_accuracy: 0.9759 - val_loss: 0.1453 - val_sparse_categorical_accuracy: 0.9707
# Epoch 18/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1513 - sparse_categorical_accuracy: 0.9769
# Epoch 00018: val_loss improved from 0.13097 to 0.12400, saving model to .\2_glorot_best_model.h5
# 202/202 [==============================] - 65s 320ms/step - loss: 0.1513 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.1240 - val_sparse_categorical_accuracy: 0.9777
# Epoch 19/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1429 - sparse_categorical_accuracy: 0.9809
# Epoch 00019: val_loss improved from 0.12400 to 0.12178, saving model to .\2_glorot_best_model.h5
# 202/202 [==============================] - 50s 246ms/step - loss: 0.1429 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.1218 - val_sparse_categorical_accuracy: 0.9791
# Epoch 20/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.1354 - sparse_categorical_accuracy: 0.9792
# Epoch 00020: val_loss did not improve from 0.12178
# ...
# Epoch 00028: val_loss did not improve from 0.09002
# 202/202 [==============================] - 48s 236ms/step - loss: 0.0924 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9888
# Epoch 29/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0914 - sparse_categorical_accuracy: 0.9893
# Epoch 00029: val_loss improved from 0.09002 to 0.08707, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.0871 - val_sparse_categorical_accuracy: 0.9888
# Epoch 30/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0822 - sparse_categorical_accuracy: 0.9922
# Epoch 00030: val_loss improved from 0.08707 to 0.07832, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.0783 - val_sparse_categorical_accuracy: 0.9930
# Epoch 31/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0776 - sparse_categorical_accuracy: 0.9939
# Epoch 00031: val_loss improved from 0.07832 to 0.07335, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 235ms/step - loss: 0.0776 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9902
# Epoch 32/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0784 - sparse_categorical_accuracy: 0.9911
# Epoch 00032: val_loss improved from 0.07335 to 0.05815, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.0581 - val_sparse_categorical_accuracy: 0.9930
# Epoch 33/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0808 - sparse_categorical_accuracy: 0.9891
# Epoch 00033: val_loss did not improve from 0.05815
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0808 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.0671 - val_sparse_categorical_accuracy: 0.9902
# Epoch 34/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0732 - sparse_categorical_accuracy: 0.9916
# Epoch 00034: val_loss did not improve from 0.05815
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0793 - val_sparse_categorical_accuracy: 0.9916
# Epoch 35/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0735 - sparse_categorical_accuracy: 0.9921
# Epoch 00035: val_loss did not improve from 0.05815
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0735 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.0585 - val_sparse_categorical_accuracy: 0.9916
# Epoch 36/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0630 - sparse_categorical_accuracy: 0.9939
# Epoch 00036: val_loss did not improve from 0.05815
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0638 - val_sparse_categorical_accuracy: 0.9902
# Epoch 37/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0622 - sparse_categorical_accuracy: 0.9943
# Epoch 00037: val_loss did not improve from 0.05815
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0622 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0625 - val_sparse_categorical_accuracy: 0.9888
# Epoch 38/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0599 - sparse_categorical_accuracy: 0.9939
# Epoch 00038: val_loss improved from 0.05815 to 0.04482, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0599 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0448 - val_sparse_categorical_accuracy: 0.9944
# Epoch 39/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0553 - sparse_categorical_accuracy: 0.9949
# Epoch 00039: val_loss improved from 0.04482 to 0.04189, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0419 - val_sparse_categorical_accuracy: 0.9972
# Epoch 40/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0541 - sparse_categorical_accuracy: 0.9953
# Epoch 00040: val_loss did not improve from 0.04189
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0438 - val_sparse_categorical_accuracy: 0.9888
# Epoch 41/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0554 - sparse_categorical_accuracy: 0.9936
# Epoch 00041: val_loss did not improve from 0.04189
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0554 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0437 - val_sparse_categorical_accuracy: 0.9902
# Epoch 42/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0553 - sparse_categorical_accuracy: 0.9952
# Epoch 00042: val_loss improved from 0.04189 to 0.03353, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 48s 235ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0335 - val_sparse_categorical_accuracy: 0.9958
# Epoch 43/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0479 - sparse_categorical_accuracy: 0.9953
# Epoch 00043: val_loss did not improve from 0.03353
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0405 - val_sparse_categorical_accuracy: 0.9972
# Epoch 44/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0470 - sparse_categorical_accuracy: 0.9957
# Epoch 00044: val_loss did not improve from 0.03353
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0417 - val_sparse_categorical_accuracy: 0.9944
# Epoch 45/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0440 - sparse_categorical_accuracy: 0.9970
# Epoch 00045: val_loss did not improve from 0.03353
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0385 - val_sparse_categorical_accuracy: 0.9972
# Epoch 46/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0462 - sparse_categorical_accuracy: 0.9955
# Epoch 00046: val_loss did not improve from 0.03353
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 0.9916
# Epoch 47/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0401 - sparse_categorical_accuracy: 0.9983
# Epoch 00047: val_loss did not improve from 0.03353
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0364 - val_sparse_categorical_accuracy: 0.9944
# Epoch 48/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0447 - sparse_categorical_accuracy: 0.9963
# Epoch 00048: val_loss improved from 0.03353 to 0.03275, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0327 - val_sparse_categorical_accuracy: 0.9944
# Epoch 49/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0387 - sparse_categorical_accuracy: 0.9969
# Epoch 00049: val_loss did not improve from 0.03275
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0340 - val_sparse_categorical_accuracy: 0.9944
# Epoch 50/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0378 - sparse_categorical_accuracy: 0.9963
# Epoch 00050: val_loss improved from 0.03275 to 0.02859, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 234ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0286 - val_sparse_categorical_accuracy: 0.9944
# Epoch 51/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0347 - sparse_categorical_accuracy: 0.9970
# Epoch 00051: val_loss improved from 0.02859 to 0.02620, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 235ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0262 - val_sparse_categorical_accuracy: 0.9972
# Epoch 52/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0347 - sparse_categorical_accuracy: 0.9958
# Epoch 00052: val_loss did not improve from 0.02620
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0408 - val_sparse_categorical_accuracy: 0.9902
# Epoch 53/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0309 - sparse_categorical_accuracy: 0.9980
# Epoch 00053: val_loss did not improve from 0.02620
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0298 - val_sparse_categorical_accuracy: 0.9958
# Epoch 54/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0352 - sparse_categorical_accuracy: 0.9969
# Epoch 00054: val_loss improved from 0.02620 to 0.02517, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 47s 235ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0252 - val_sparse_categorical_accuracy: 0.9958
# Epoch 55/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0327 - sparse_categorical_accuracy: 0.9972
# Epoch 00055: val_loss did not improve from 0.02517
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0331 - val_sparse_categorical_accuracy: 0.9972
# Epoch 56/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0325 - sparse_categorical_accuracy: 0.9966
# Epoch 00056: val_loss did not improve from 0.02517
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0342 - val_sparse_categorical_accuracy: 0.9958
# Epoch 57/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0355 - sparse_categorical_accuracy: 0.9950
# Epoch 00057: val_loss improved from 0.02517 to 0.02322, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 48s 237ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9972
# Epoch 58/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0290 - sparse_categorical_accuracy: 0.9977
# Epoch 00058: val_loss did not improve from 0.02322
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0312 - val_sparse_categorical_accuracy: 0.9958
# Epoch 59/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0331 - sparse_categorical_accuracy: 0.9964
# Epoch 00059: val_loss improved from 0.02322 to 0.02030, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 48s 235ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9986
# Epoch 60/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0289 - sparse_categorical_accuracy: 0.9975
# Epoch 00060: val_loss did not improve from 0.02030
# 202/202 [==============================] - 50s 249ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0318 - val_sparse_categorical_accuracy: 0.9972
# Epoch 61/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0270 - sparse_categorical_accuracy: 0.9980
# Epoch 00061: val_loss improved from 0.02030 to 0.01608, saving model to .\10_glorot_best_model.h5
# 202/202 [==============================] - 48s 239ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 0.9986
# Epoch 62/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0229 - sparse_categorical_accuracy: 0.9991
# Epoch 00062: val_loss did not improve from 0.01608
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0229 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0283 - val_sparse_categorical_accuracy: 0.9958
# Epoch 63/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0239 - sparse_categorical_accuracy: 0.9989
# Epoch 00063: val_loss did not improve from 0.01608
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0239 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9986
# Epoch 64/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0219 - sparse_categorical_accuracy: 0.9988
# Epoch 00064: val_loss did not improve from 0.01608
# 202/202 [==============================] - 47s 233ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9972
# Epoch 65/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0233 - sparse_categorical_accuracy: 0.9988
# Epoch 00065: val_loss did not improve from 0.01608
# 202/202 [==============================] - 47s 232ms/step - loss: 0.0233 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9958
# Epoch 66/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0211 - sparse_categorical_accuracy: 0.9989
# Epoch 00066: val_loss did not improve from 0.01608
# 202/202 [==============================] - 47s 231ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9972
# Epoch 67/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0203 - sparse_categorical_accuracy: 0.9991
# Epoch 00067: val_loss did not improve from 0.01608
# 202/202 [==============================] - 45s 225ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0254 - val_sparse_categorical_accuracy: 0.9958
# Epoch 68/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0247 - sparse_categorical_accuracy: 0.9970
# Epoch 00068: val_loss did not improve from 0.01608
# 202/202 [==============================] - 44s 220ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0255 - val_sparse_categorical_accuracy: 0.9944
# Epoch 69/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0253 - sparse_categorical_accuracy: 0.9967
# Epoch 00069: val_loss did not improve from 0.01608
# 202/202 [==============================] - 44s 220ms/step - loss: 0.0253 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0241 - val_sparse_categorical_accuracy: 0.9972
# Epoch 70/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0211 - sparse_categorical_accuracy: 0.9980
# Epoch 00070: val_loss did not improve from 0.01608
# 202/202 [==============================] - 49s 242ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0306 - val_sparse_categorical_accuracy: 0.9944
# Epoch 71/1000
# 202/202 [==============================] - ETA: 0s - loss: 0.0222 - sparse_categorical_accuracy: 0.9975
# Epoch 00071: val_loss did not improve from 0.01608
# 202/202 [==============================] - 53s 261ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0266 - val_sparse_categorical_accuracy: 0.9944
# Epoch 00071: early stopping
# 52/52 [==============================] - 5s 90ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9934
# ****************************************************************************************************
# End of fold: 10
# ****************************************************************************************************

# %%
for i in range(len(avg_val_loss)):
    print('*'*100)
    print(f'Fold: {i+1}')
    print(f'Avg Val Loss: {round(avg_val_loss[i], ndigits=3)}')
    print(f'Avg Val Acc: {round(avg_val_acc[i]*100, ndigits=3)}')
    print(f'Eval Loss: {round(eval_loss[i], ndigits=3)}')
    print(f'Eval Acc: {round(eval_acc[i]*100, ndigits=3)}')
# Out:
# ****************************************************************************************************
# Fold: 1
# Avg Val Loss: 0.111
# Avg Val Acc: 97.164
# Eval Loss: 0.011
# Eval Acc: 99.759
# ****************************************************************************************************
# Fold: 2
# Avg Val Loss: 0.129
# Avg Val Acc: 96.604
# Eval Loss: 0.019
# Eval Acc: 99.639
# ****************************************************************************************************
# Fold: 3
# Avg Val Loss: 0.118
# Avg Val Acc: 97.306
# Eval Loss: 0.014
# Eval Acc: 99.819
# ****************************************************************************************************
# Fold: 4
# Avg Val Loss: 0.091
# Avg Val Acc: 97.709
# Eval Loss: 0.011
# Eval Acc: 99.699
# ****************************************************************************************************
# Fold: 5
# Avg Val Loss: 0.13
# Avg Val Acc: 96.651
# Eval Loss: 0.022
# Eval Acc: 99.639
# ****************************************************************************************************
# Fold: 6
# Avg Val Loss: 0.171
# Avg Val Acc: 96.286
# Eval Loss: 0.045
# Eval Acc: 99.218
# ****************************************************************************************************
# Fold: 7
# Avg Val Loss: 0.085
# Avg Val Acc: 97.981
# Eval Loss: 0.018
# Eval Acc: 99.519
# ****************************************************************************************************
# Fold: 8
# Avg Val Loss: 0.118
# Avg Val Acc: 97.643
# Eval Loss: 0.015
# Eval Acc: 99.759
# ****************************************************************************************************
# Fold: 9
# Avg Val Loss: 0.156
# Avg Val Acc: 96.38
# Eval Loss: 0.025
# Eval Acc: 99.398
# ****************************************************************************************************
# Fold: 10
# Avg Val Loss: 0.172
# Avg Val Acc: 95.666
# Eval Loss: 0.033
# Eval Acc: 99.338

# %%
print('*'*100)
print(f'Final Avg Loss: {round(np.mean(avg_val_loss), ndigits=3)} (+/-{round(np.std(avg_val_loss), ndigits=3)})') 
print(f'Final Avg Val Acc: {round(np.mean(avg_val_acc), ndigits=3)} (+/-{round(np.std(avg_val_acc), ndigits=3)})')
print(f'Final Eval Loss: {round(np.mean(eval_loss), ndigits=3)} (+/-{round(np.std(eval_loss), ndigits=3)})')
print(f'Final Eval Acc: {round(np.mean(eval_acc), ndigits=3)} (+/-{round(np.std(eval_acc), ndigits=3)})')
# Out:
# ****************************************************************************************************
# Final Avg Loss: 0.128 (+/-0.029)
# Final Avg Val Acc: 0.969 (+/-0.007)
# Final Eval Loss: 0.021 (+/-0.01)
# Final Eval Acc: 0.996 (+/-0.002)

# %% [markdown]
# ##### Full training

# %%
results_df = pd.DataFrame({'results':[100,76,84,85,73,73,119,113,68,61]})

# %%
results_df.describe()
# Out:
#           results
# count   10.000000
# mean    85.200000
# std     19.435363
# min     61.000000
# 25%     73.000000
# 50%     80.000000
# 75%     96.250000
# max    119.000000

# %%
results_df.quantile(q=0.95)
# Out:
# results    116.3
# Name: 0.95, dtype: float64

# %%
results_df.boxplot()

# %%
train_num_batches = train_dataset.cardinality().numpy()
# val_num_batches = val_dataset.cardinality().numpy()

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(buffer_size=(train_num_batches*batch_size), seed=random_seed).prefetch(buffer_size=AUTOTUNE)
# val_dataset = val_dataset.cache().shuffle(buffer_size=(val_num_batches*batch_size), seed=random_seed).prefetch(buffer_size=AUTOTUNE)

# %%
model = create_model()

# %%
# early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
#                                               min_delta=0, 
#                                               patience=10, 
#                                               verbose=1, 
#                                               mode='min',
#                                               baseline=None, 
#                                               restore_best_weights=False)

# %%
# checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath='./glorot_best_model.h5', 
#                                                 monitor='val_loss',
#                                                 verbose=1,
#                                                 save_best_only=True, 
#                                                 mode='min')

# %%
epochs = 116

history = model.fit(train_dataset, 
#                     validation_data=val_dataset,
                    epochs=epochs,
                    verbose=1, 
#                     callbacks=[early_stop, checkpoint]
                   )
# Out:
# Epoch 1/116
#   2/224 [..............................] - ETA: 32s - loss: 2.9901 - sparse_categorical_accuracy: 0.1406WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0809s vs `on_train_batch_end` time: 0.2018s). Check your callbacks.
# 224/224 [==============================] - 60s 269ms/step - loss: 2.0000 - sparse_categorical_accuracy: 0.3230
# Epoch 2/116
# 224/224 [==============================] - 56s 248ms/step - loss: 1.2495 - sparse_categorical_accuracy: 0.5776
# Epoch 3/116
# 224/224 [==============================] - 57s 256ms/step - loss: 0.8994 - sparse_categorical_accuracy: 0.7027
# Epoch 4/116
# 224/224 [==============================] - 59s 264ms/step - loss: 0.7219 - sparse_categorical_accuracy: 0.7750
# Epoch 5/116
# 224/224 [==============================] - 59s 263ms/step - loss: 0.5948 - sparse_categorical_accuracy: 0.8285
# Epoch 6/116
# 224/224 [==============================] - 57s 255ms/step - loss: 0.4999 - sparse_categorical_accuracy: 0.8661
# Epoch 7/116
# 224/224 [==============================] - 59s 263ms/step - loss: 0.4249 - sparse_categorical_accuracy: 0.8952
# Epoch 8/116
# 224/224 [==============================] - 59s 264ms/step - loss: 0.3628 - sparse_categorical_accuracy: 0.9177
# Epoch 9/116
# 224/224 [==============================] - 59s 264ms/step - loss: 0.3183 - sparse_categorical_accuracy: 0.9322
# Epoch 10/116
# 224/224 [==============================] - 59s 265ms/step - loss: 0.2914 - sparse_categorical_accuracy: 0.9441
# Epoch 11/116
# 224/224 [==============================] - 59s 264ms/step - loss: 0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 9,152,500
# Trainable params: 9,147,566
# Non-trainable params: 4,934
# _________________________________________________________________

# %%
model.save('./full_train_model.h5')

# %%
# plt.figure(figsize=(30, 15))
# acc = history.history['sparse_categorical_accuracy']
# val_acc = history.history['val_sparse_categorical_accuracy']

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs_range = range(len(acc))

# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()

# %%
sp_acc = history.history['sparse_categorical_accuracy']
sp_loss = history.history['loss']
# val_acc = history.history['val_sparse_categorical_accuracy']
# val_loss = history.history['val_loss']

print(f'Avg Acc: {round(np.mean(sp_acc), ndigits=4)} (+/-{round(np.std(sp_acc), ndigits=4)})')
print(f'Avg Loss: {round(np.mean(sp_loss), ndigits=4)} (+/-{round(np.std(sp_loss), ndigits=4)})')
# print(f'Avg Val Acc: {round(np.mean(val_acc), ndigits=4)} (+/-{round(np.std(val_acc), ndigits=4)})')
# print(f'Avg Val Loss: {round(np.mean(val_loss), ndigits=4)} (+/-{round(np.std(val_loss), ndigits=4)})')
# Out:
# Avg Acc: 0.9763 (+/-0.0828)
# Avg Loss: 0.1039 (+/-0.25)

# %%
model = load_model('./full_train_model.h5')

# %%
# plt.figure(figsize=(30, 20))
# plt.rcParams['axes.titlesize'] = 20

# for images, labels in test_dataset.take(1):
#     for i in range(9):
#         ax = plt.subplot(3, 3, i + 1)
#         img_arr = keras.preprocessing.image.img_to_array(images[i])
#         plt.imshow(img_arr.astype("uint8"))
#         img_arr = tf.expand_dims(img_arr, 0)
#         pred = model.predict(img_arr)
#         scores = tf.nn.softmax(pred[0])
#         pred_class = np.argmax(scores)
#         print(f'Label: {class_names[labels[i]]}, Predicted: {class_names[pred_class]}')
#         plt.title(f'Predicted Class: {class_names[pred_class]}')

# %%
# keras.utils.plot_model(model, show_shapes=True)

# %%
# def make_predictions(directory, img_name):
# #     plt.figure(figsize=(5, 5))
# #     plt.rcParams['axes.titlesize'] = 20
#     test_img = keras.preprocessing.image.load_img(f'{directory}/{img_name}',
#                                                  target_size=(img_height, img_width))

#     img_arr = keras.preprocessing.image.img_to_array(test_img)
# #     plt.imshow(img_arr.astype("uint8"))
#     img_arr = tf.expand_dims(img_arr, 0)

#     pred = model.predict(img_arr)
#     scores = tf.nn.softmax(pred[0])
#     pred_class = np.argmax(scores)
#     return class_names[pred_class]
    
# #     print(class_names[pred_class])
# #     plt.title(f'Predicted Class: {class_names[pred_class]}')

# %%
print(class_names)
# Out:
# ['body', 'conditioner', 'cotton', 'facial', 'sebum', 'serum', 'shampoo', 'toner']

# %%
# Train
# 0.9997
print(model.evaluate(train_dataset, return_dict=True))
# Out:
# 224/224 [==============================] - 15s 65ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9997
# {'loss': 0.002499798545613885, 'sparse_categorical_accuracy': 0.9997204542160034}

# %%
# # Val
# # 0.9995
# print(model.evaluate(val_dataset, return_dict=True))

# %%
# Test
# .9935
print(model.evaluate(test_dataset, return_dict=True))
# Out:
# 52/52 [==============================] - 5s 105ms/step - loss: 0.0059 - sparse_categorical_accuracy: 1.0000
# {'loss': 0.005864111240953207, 'sparse_categorical_accuracy': 1.0}

# %%
# plt.figure(figsize=(30, 20))
# plt.rcParams['axes.titlesize'] = 20
y_true, y_pred, y_pred_scores = [], [], []

for images, labels in test_dataset.take(-1):
    for i in range(len(labels)):
        y_true.append(labels[i])
        img_arr = keras.preprocessing.image.img_to_array(images[i])
        img_arr = tf.expand_dims(img_arr, 0)
        pred = model.predict(img_arr)
        scores = tf.nn.softmax(pred[0])
        pred_class = np.argmax(scores)
        y_pred.append(pred_class)
        y_pred_scores.append(scores)
        
#         ax = plt.subplot(3, 3, i + 1)
#         if labels[i] != pred_class:
#             print(f'item:{i+1}, y_true:{class_names[labels[i]]}, y_pred:{class_names[pred_class]}')
#             plt.imsave(fname=f'{i}-y_true-{class_names[labels[i]]}-y_pred-{class_names[pred_class]}.jpg',
#                        arr=images[i].numpy().astype("uint8"), 
#                        format='jpg')
#             plt.title(f'y_true:{class_names[labels[i]]}, y_pred:{class_names[pred_class]}')
#             plt.axis("off")
#         print(f'Label: {class_names[labels[i]]}, Predicted: {class_names[pred_class]}')

# %%
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#         body     1.0000    1.0000    1.0000       263
#  conditioner     1.0000    1.0000    1.0000       214
#       cotton     1.0000    1.0000    1.0000       205
#       facial     1.0000    1.0000    1.0000        60
#        sebum     1.0000    1.0000    1.0000       250
#        serum     1.0000    1.0000    1.0000       340
#      shampoo     1.0000    1.0000    1.0000       170
#        toner     1.0000    1.0000    1.0000       160
#
#     accuracy                         1.0000      1662
#    macro avg     1.0000    1.0000    1.0000      1662
# weighted avg     1.0000    1.0000    1.0000      1662

# %%
sns.set(rc={'figure.figsize':(15, 10)})

cm_normalized = pd.DataFrame(confusion_matrix(y_true, y_pred, normalize='true'), 
                             class_names, 
                             class_names,
                             dtype=float)
sns.heatmap(cm_normalized, annot=True, cmap='Blues')

# %%
cm = pd.DataFrame(data=confusion_matrix(y_true, y_pred), 
                  index=class_names, 
                  columns=class_names)
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')

# %%
current_auc = roc_auc_score(y_true, y_pred_scores, multi_class='ovr', average='weighted')
best_auc = 0.9999832788371464 # 0.9999987218617872
print(f'Current AUC: {current_auc}, Best AUC: {best_auc}')    
print(current_auc > best_auc)
# Out:
# Current AUC: 1.0, Best AUC: 0.9999832788371464
# True

# %%
for class_name in class_names:
    check_predictions(class_name)
    print('\n')
    print('*'*100)
# Out:
# Predicting for: body
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
# Predicting for: conditioner
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
# Predicting for: cotton
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
# Predicting for: facial
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
# Predicting for: sebum
# Predicted: serum for: 2020-10-30-17-08-38-image.jpg
# Predicted: serum for: 2020-10-30-17-08-39-image.jpg
# Number of misclassifications: 2
#
#
# ****************************************************************************************************
# Predicting for: serum
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
# Predicting for: shampoo
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
# Predicting for: toner
# Number of misclassifications: 0
#
#
# ****************************************************************************************************
